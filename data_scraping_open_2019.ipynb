# %% [markdown]
# # Imports

# %%
import pandas as pd
import requests
import nbimporter
from nbimporter import NotebookLoader

loader = NotebookLoader('.')
module = loader.load_module('data_scraping_functions')

from data_scraping_functions import scraping_data_open_and_games

# %% [markdown]
# # Definitions

# %%
year = 2019
competition = "open"
base_path = "C:/Users/Zi/Documents/data-science-crossfit/"

# %% [markdown]
# # Data Scraping

# %%
# Scrape data for the 'open' competition and the current year
df_open_year = scraping_data_open_and_games(year, competition)
# Add a new column 'genderId' with the value of 'divisionId' for consistency
df_open_year['genderId'] = df_open_year['divisionId']
# Drop irrelevant columns
df_open_year = df_open_year.drop(columns=['postCompStatus', 'profilePicS3key', 'countryShortCode', 'teamCaptain', 'divisionId'])
# Add a new column 'year' with the current year
df_open_year['year'] = year
# Print the consolidated DataFrame
df_open_year
# Out:
#        competitorId             competitorName      firstName      lastName  \
# 0            153604              Mathew Fraser         Mathew        Fraser
# 1             81616  Björgvin Karl Guðmundsson  Björgvin Karl   Guðmundsson
# 2            199938              Jacob Heppner          Jacob       Heppner
# 3            514502       Lefteris Theofanidis       Lefteris   Theofanidis
# 4            308712     Jean-Simon Roy-Lemaire     Jean-Simon   Roy-Lemaire
# ...             ...                        ...            ...           ...
# 341920       146572  Andréa Maria Cecil Topper   Andréa Maria  Cecil Topper
# 341921      1147531                Bary Morton           Bary        Morton
# 341922       681265             Melissa Yinger        Melissa        Yinger
# 341923       332049               Tamara Meyer         Tamara         Meyer
# 341924        15689              Angela Forbes         Angela        Forbes
#
#        status gender countryOfOriginCode countryOfOriginName regionId  \
# 0         ACT      M                  US       United States     None
# 1         ACT      M                  IS             Iceland     None
# 2         ACT      M                  US       United States     None
# 3         ACT      M                  GR              Greece     None
# 4         ACT      M                  CA              Canada     None
# ...       ...    ...                 ...                 ...      ...
# 341920    ACT      F                  US       United States     None
# 341921    ACT      F                  US       United States     None
# 341922    ACT      F                  US       United States     None
# 341923    ACT      F                  US       United States     None
# 341924    ACT      F                  US       United States     None
#
#        regionName affiliateId            affiliateName age  height  weight  \
# 0                        3220          CrossFit Mayhem  29   67 in  195 lb
# 1                        4860         CrossFit Hengill  26  178 cm  190 lb
# 2                       13888   Cobra Command CrossFit  29   67 in  195 lb
# 3                        6356      CrossFit North Zone  29  171 cm   81 kg
# 4                        4459           Tonic CrossFit  25  176 cm  195 lb
# ...           ...         ...                      ...  ..     ...     ...
# 341920                    574  CrossFit Silicon Valley  41   69 in  140 lb
# 341921                   None                           32
# 341922                    625      CrossFit Santa Cruz  35
# 341923                  19273              CrossFit HQ  50   65 in  135 lb
# 341924                    625      CrossFit Santa Cruz  41
#
#        overallRank overallScore genderId  year
# 0                1           66        1  2019
# 1                2           93        1  2019
# 2                3          168        1  2019
# 3                4          183        1  2019
# 4                5          187        1  2019
# ...            ...          ...      ...   ...
# 341920      140133       604776       13  2019
# 341921      140133       604776        2  2019
# 341922      140133       604776       19  2019
# 341923      140133       604776        6  2019
# 341924      140133       604776       13  2019
#
# [341925 rows x 19 columns]

# %% [markdown]
# # Exports

# %%
df_open_year.to_csv(base_path + "csv_files/version_1_raw_data/df_open_" + str(year) + ".csv", index=False)
