# %% [markdown]
# # Imports

# %%
import pandas as pd
import requests
import nbimporter
from nbimporter import NotebookLoader

loader = NotebookLoader('.')
module = loader.load_module('data_scraping_functions')

from data_scraping_functions import scraping_data_open_and_games

# %% [markdown]
# # Definitions

# %%
year = 2014
competition = "open"
base_path = "C:/Users/Zi/Documents/data-science-crossfit/"

# %% [markdown]
# # Data Scraping

# %%
# Scrape data for the 'open' competition and the current year
df_open_year = scraping_data_open_and_games(year, competition)
# Add a new column 'genderId' with the value of 'divisionId' for consistency
df_open_year['genderId'] = df_open_year['divisionId']
# Drop irrelevant columns
df_open_year = df_open_year.drop(columns=['postCompStatus', 'profilePicS3key', 'countryShortCode', 'teamCaptain', 'divisionId'])
# Add a new column 'year' with the current year
df_open_year['year'] = year
# Print the consolidated DataFrame
df_open_year
# Out:
#        competitorId      competitorName firstName   lastName status gender  \
# 0             11435        Rich Froning      Rich    Froning    ACT      M
# 1             12485       Jason Khalipa     Jason    Khalipa    ACT      M
# 2             43761           Ben Smith       Ben      Smith    ACT      M
# 3             47661          Dan Bailey       Dan     Bailey    ACT      M
# 4             34796       Scott Panchik     Scott    Panchik    ACT      M
# ...             ...                 ...       ...        ...    ...    ...
# 132355       318390        Annie Modica     Annie     Modica    ACT      F
# 132356       270521    Jennifer Swentek  Jennifer    Swentek    ACT      F
# 132357       284402        Megan Buskey     Megan     Buskey    ACT      F
# 132358       383768     Erica Frederick     Erica  Frederick    ACT      F
# 132359       285539  Kathleen Menchetti  Kathleen  Menchetti    ACT      F
#
#        countryOfOriginCode countryOfOriginName regionId           regionName  \
# 0                                                     6         Central East
# 1                                                    12  Northern California
# 2                                                     9         Mid Atlantic
# 3                                                    16  Southern California
# 4                                                     6         Central East
# ...                    ...                 ...      ...                  ...
# 132355                                               11           North East
# 132356                                               16  Southern California
# 132357                                                9         Mid Atlantic
# 132358                                               15           South East
# 132359                                                9         Mid Atlantic
#
#        affiliateId       affiliateName age height weight overallRank  \
# 0             3220     CrossFit Mayhem  26                         1
# 1             2605                      28                         2
# 2             4933    CrossFit Krypton  24                         3
# 3                0                      30                         4
# 4             7991  CrossFit Mentality  26                         5
# ...            ...                 ...  ..    ...    ...         ...
# 132355        5565                      24                       ACT
# 132356        2957                      33                       ACT
# 132357         791         CrossFit DC  32                       ACT
# 132358        6875                      32                       ACT
# 132359        7255                      42                       ACT
#
#        overallScore genderId  year
# 0                18        1  2014
# 1                72        1  2014
# 2                92        1  2014
# 3               122        1  2014
# 4               157        1  2014
# ...             ...      ...   ...
# 132355            0        2  2014
# 132356            0        2  2014
# 132357            0        2  2014
# 132358            0        2  2014
# 132359            0       13  2014
#
# [132360 rows x 19 columns]

# %% [markdown]
# # Exports

# %%
df_open_year.to_csv(base_path + "csv_files/version_1_raw_data/df_open_" + str(year) + ".csv", index=False)
