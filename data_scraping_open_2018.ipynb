# %% [markdown]
# # Imports

# %%
import pandas as pd
import requests
import nbimporter
from nbimporter import NotebookLoader

loader = NotebookLoader('.')
module = loader.load_module('data_scraping_functions')

from data_scraping_functions import scraping_data_open_and_games

# %% [markdown]
# # Definitions

# %%
year = 2018
competition = "open"
base_path = "C:/Users/Zi/Documents/data-science-crossfit/"

# %% [markdown]
# # Data Scraping

# %%
# Scrape data for the 'open' competition and the current year
df_open_year = scraping_data_open_and_games(year, competition)
# Add a new column 'genderId' with the value of 'divisionId' for consistency
df_open_year['genderId'] = df_open_year['divisionId']
# Drop irrelevant columns
df_open_year = df_open_year.drop(columns=['postCompStatus', 'profilePicS3key', 'countryShortCode', 'teamCaptain', 'divisionId'])
# Add a new column 'year' with the current year
df_open_year['year'] = year
# Print the consolidated DataFrame
df_open_year
# Out:
#        competitorId          competitorName   firstName     lastName status  \
# 0            153604           Mathew Fraser      Mathew       Fraser    ACT
# 1            180541          Alex Vigneault        Alex    Vigneault    ACT
# 2            702092           Willy Georges       Willy      Georges    ACT
# 3            308712  Jean-Simon Roy-Lemaire  Jean-Simon  Roy-Lemaire    ACT
# 4            158264         Patrick Vellner     Patrick      Vellner    ACT
# ...             ...                     ...         ...          ...    ...
# 399533      1206428           Olivia LeFort      Olivia       LeFort    ACT
# 399534       993494            Kari Thacker        Kari      Thacker    ACT
# 399535       226604             Kyla Hayden        Kyla       Hayden    ACT
# 399536       110102       Heather Rosenberg     Heather    Rosenberg    ACT
# 399537      1170775             Rose Carman        Rose       Carman    ACT
#
#        gender countryOfOriginCode countryOfOriginName regionId    regionName  \
# 0           M                  US       United States        6  Central East
# 1           M                  CA              Canada       18   Canada East
# 2           M                  FR              France       24  Europe South
# 3           M                  CA              Canada       18   Canada East
# 4           M                  CA              Canada       18   Canada East
# ...       ...                 ...                 ...      ...           ...
# 399533      F                  US       United States       11    North East
# 399534      F                  US       United States       19    West Coast
# 399535      F                  US       United States       19    West Coast
# 399536      F                  US       United States       19    West Coast
# 399537      F                  US       United States       19    West Coast
#
#        affiliateId          affiliateName age  height  weight overallRank  \
# 0             3220        CrossFit Mayhem  28   67 in  195 lb           1
# 1            10990   CrossFit Quebec City  26   71 in  205 lb           2
# 2            16786        CrossFit DBS 83  25  179 cm   88 kg           3
# 3             4459         Tonic CrossFit  24  176 cm  195 lb           4
# 4             6214  CrossFit Solid Ground  28   71 in  195 lb           5
# ...            ...                    ...  ..     ...     ...         ...
# 399533        5965       CrossFit Meriden  20   62 in  180 lb      165829
# 399534        3029       Maltese CrossFit  35   68 in  235 lb      165829
# 399535       18658      CrossFit HQ South  39   64 in  130 lb      165829
# 399536       18658      CrossFit HQ South  32   67 in  140 lb      165829
# 399537         625    CrossFit Santa Cruz  26   66 in  140 lb      165829
#
#        overallScore genderId  year
# 0                97        1  2018
# 1               439        1  2018
# 2               596        1  2018
# 3               681        1  2018
# 4               706        1  2018
# ...             ...      ...   ...
# 399533       888711        2  2018
# 399534       888711       19  2018
# 399535       888711       19  2018
# 399536       888711        2  2018
# 399537       888711        2  2018
#
# [399538 rows x 19 columns]

# %% [markdown]
# # Exports

# %%
df_open_year.to_csv(base_path + "csv_files/version_1_raw_data/df_open_" + str(year) + ".csv", index=False)
