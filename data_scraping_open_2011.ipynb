# %% [markdown]
# # Imports

# %%
import pandas as pd
import requests
import nbimporter
from nbimporter import NotebookLoader

loader = NotebookLoader('.')
module = loader.load_module('data_scraping_functions')

from data_scraping_functions import scraping_data_open_and_games

# %% [markdown]
# # Definitions

# %%
year = 2011
competition = "open"
base_path = "C:/Users/Zi/Documents/data-science-crossfit/"

# %% [markdown]
# # Data Scraping

# %%
# Scrape data for the 'open' competition and the current year
df_open_year = scraping_data_open_and_games(year, competition)
# Add a new column 'genderId' with the value of 'divisionId' for consistency
df_open_year['genderId'] = df_open_year['divisionId']
# Drop irrelevant columns
df_open_year = df_open_year.drop(columns=['postCompStatus', 'profilePicS3key', 'countryShortCode', 'teamCaptain', 'divisionId'])
# Add a new column 'year' with the current year
df_open_year['year'] = year
# Print the consolidated DataFrame
df_open_year
# Out:
#       competitorId         competitorName firstName          lastName status  \
# 0            47661             Dan Bailey       Dan            Bailey    ACT
# 1           124483         Joshua Bridges    Joshua           Bridges    ACT
# 2            11435           Rich Froning      Rich           Froning    ACT
# 3           151906             Mikko Salo     Mikko              Salo    ACT
# 4            10169        Austin Malleolo    Austin          Malleolo    ACT
# ...            ...                    ...       ...               ...    ...
# 13121       962048          sarah stewart     Sarah           Stewart    ACT
# 13122      2154501  Jana Rós Reynisdóttir      Jana  Rós Reynisdóttir    ACT
# 13123        31653      alycia eisenstein    alycia        eisenstein    ACT
# 13124      2154502            Lara Struik      Lara            Struik    ACT
# 13125      2154503        Christie Pearce  Christie            Pearce    ACT
#
#       gender countryOfOriginCode countryOfOriginName regionId  \
# 0          M                                                6
# 1          M                                               16
# 2          M                                                6
# 3          M                                                7
# 4          M                                               11
# ...      ...                 ...                 ...      ...
# 13121      F                                                7
# 13122      F                                                7
# 13123      F                                               10
# 13124      F                                                3
# 13125      F                                                3
#
#                 regionName affiliateId        affiliateName age height weight  \
# 0             Central East           0      CrossFit Legacy  27
# 1      Southern California           0    CrossFit Invictus  28
# 2             Central East           0       CrossFit Faith  23
# 3                   Europe           0        CrossFit Pori  31
# 4               North East           0  Reebok CrossFit One  24
# ...                    ...         ...                  ...  ..    ...    ...
# 13121               Europe           0       CrossFit Leeds  34
# 13122               Europe           0       CrossFit Sport  10
# 13123        North Central           0  Windy City CrossFit  35
# 13124            Australia           0        CrossFit 4551  10
# 13125            Australia           0     CrossFit NorWest  10
#
#       overallRank overallScore genderId  year
# 0               1           43        1  2011
# 1               2           44        1  2011
# 2               3           61        1  2011
# 3               4           75        1  2011
# 4               5          112        1  2011
# ...           ...          ...      ...   ...
# 13121        4502        33227        2  2011
# 13122        4503        33316        2  2011
# 13123        4504        33335        2  2011
# 13124        4505        33497        2  2011
# 13125        4506        34217        2  2011
#
# [13126 rows x 19 columns]

# %% [markdown]
# # Exports

# %%
df_open_year.to_csv(base_path + "csv_files/version_1_raw_data/df_open_" + str(year) + ".csv", index=False)
