# %% [markdown]
# # Imports

# %%
import pandas as pd
import requests
import nbimporter
from nbimporter import NotebookLoader

loader = NotebookLoader('.')
module = loader.load_module('data_scraping_functions')

from data_scraping_functions import scraping_data_open_and_games

# %% [markdown]
# # Definitions

# %%
year = 2015
competition = "open"
base_path = "C:/Users/Zi/Documents/data-science-crossfit/"

# %% [markdown]
# # Data Scraping

# %%
# Scrape data for the 'open' competition and the current year
df_open_year = scraping_data_open_and_games(year, competition)
# Add a new column 'genderId' with the value of 'divisionId' for consistency
df_open_year['genderId'] = df_open_year['divisionId']
# Drop irrelevant columns
df_open_year = df_open_year.drop(columns=['postCompStatus', 'profilePicS3key', 'countryShortCode', 'teamCaptain', 'divisionId'])
# Add a new column 'year' with the current year
df_open_year['year'] = year
# Print the consolidated DataFrame
df_open_year
# Out:
#        competitorId               competitorName firstName  \
# 0            153604                Mathew Fraser    Mathew
# 1             11435          Richard Froning Jr.   Richard
# 2             43761                    Ben Smith       Ben
# 3             12485                Jason Khalipa     Jason
# 4             34796                Scott Panchik     Scott
# ...             ...                          ...       ...
# 262031       574501              Shanna Peterson    Shanna
# 262032       240599             Tiffany Chambers   Tiffany
# 262033       619780                 Dana Abdulla      Dana
# 262034       393623  Giovanna de Beij Mazariegos  Giovanna
# 262035       495064                Rafaela Rocha   Rafaela
#
#                   lastName status gender countryOfOriginCode  \
# 0                   Fraser    ACT      M
# 1              Froning Jr.    ACT      M
# 2                    Smith    ACT      M
# 3                  Khalipa    ACT      M
# 4                  Panchik    ACT      M
# ...                    ...    ...    ...                 ...
# 262031            Peterson    ACT      F
# 262032            Chambers    ACT      F
# 262033             Abdulla    ACT      F
# 262034  de Beij Mazariegos    ACT      F
# 262035               Rocha    ACT      F
#
#        countryOfOriginName regionId           regionName affiliateId  \
# 0                                11           North East        2080
# 1                                 6         Central East        3220
# 2                                 9         Mid Atlantic        4933
# 3                                12  Northern California        2605
# 4                                 6         Central East        7991
# ...                    ...      ...                  ...         ...
# 262031                           17           South West         630
# 262032                           12  Northern California        2688
# 262033                            1               Africa        6353
# 262034                            7               Europe        3280
# 262035                            8        Latin America       10492
#
#                     affiliateName age height weight overallRank overallScore  \
# 0       Champlain Valley CrossFit  25                         1          127
# 1                 CrossFit Mayhem  27                         2          140
# 2                CrossFit Krypton  25                         3          183
# 3                                  29                         4          260
# 4              CrossFit Mentality  27                         5          294
# ...                           ...  ..    ...    ...         ...          ...
# 262031               MBS CrossFit  43                       ACT            0
# 262032                             31                       ACT            0
# 262033            CrossFit Delmon  25                       ACT            0
# 262034           Mobilis CrossFit  39                       ACT            0
# 262035                             27                       ACT            0
#
#        genderId  year
# 0             1  2015
# 1             1  2015
# 2             1  2015
# 3             1  2015
# 4             1  2015
# ...         ...   ...
# 262031       13  2015
# 262032        2  2015
# 262033        2  2015
# 262034        2  2015
# 262035        2  2015
#
# [262036 rows x 19 columns]

# %% [markdown]
# # Exports

# %%
df_open_year.to_csv(base_path + "csv_files/version_1_raw_data/df_open_" + str(year) + ".csv", index=False)
